# %% [markdown]
# # Relatorio de Análise I

# %% [markdown]
# ## Importando a base dados

# %% [markdown]
# Z

# %%
import pandas as pd

# %%
# importando
pd.read_csv('dados/aluguel.csv',sep=';')
# Out:
#                           Tipo                    Bairro  Quartos  Vagas  \
# 0                    Quitinete                Copacabana        1      0
# 1                         Casa           Jardim Botânico        2      0
# 2      Conjunto Comercial/Sala           Barra da Tijuca        0      4
# 3                  Apartamento                    Centro        1      0
# 4                  Apartamento              Higienópolis        1      0
# 5                  Apartamento              Vista Alegre        3      1
# 6                  Apartamento                  Cachambi        2      0
# 7           Casa de Condomínio           Barra da Tijuca        5      4
# 8           Casa de Condomínio                     Ramos        2      2
# 9      Conjunto Comercial/Sala                    Centro        0      3
# 10                 Apartamento                    Centro        1      0
# 11                 Apartamento                    Grajaú        2      1
# ...

# %%
dados = pd.read_csv('dados/aluguel.csv', sep=';')

# %%
dados
# Out:
#                           Tipo                    Bairro  Quartos  Vagas  \
# 0                    Quitinete                Copacabana        1      0
# 1                         Casa           Jardim Botânico        2      0
# 2      Conjunto Comercial/Sala           Barra da Tijuca        0      4
# 3                  Apartamento                    Centro        1      0
# 4                  Apartamento              Higienópolis        1      0
# 5                  Apartamento              Vista Alegre        3      1
# 6                  Apartamento                  Cachambi        2      0
# 7           Casa de Condomínio           Barra da Tijuca        5      4
# 8           Casa de Condomínio                     Ramos        2      2
# 9      Conjunto Comercial/Sala                    Centro        0      3
# 10                 Apartamento                    Centro        1      0
# 11                 Apartamento                    Grajaú        2      1
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
# Tipo          32960 non-null object
# Bairro        32960 non-null object
# Quartos       32960 non-null int64
# Vagas         32960 non-null int64
# Suites        32960 non-null int64
# Area          32960 non-null int64
# Valor         32943 non-null float64
# Condominio    28867 non-null float64
# IPTU          22723 non-null float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %% [markdown]
# ## Informações Gerais sobre a Base de Dados

# %%
dados.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, columns=['Tipos de Dados'])

# %%
tipos_de_dados.columns.name = 'Variaveis'
tipos_de_dados
# Out:
# Variaveis  Tipos de Dados
# Tipo               object
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Valor             float64
# Condominio        float64
# IPTU              float64

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.shape[0]
# Out:
# 32960

# %%
dados.shape[1]
# Out:
# 9

# %%
print('A base de dados apresenta {} registro (imoveis) e {} variaveis'.format(dados.shape[0], dados.shape[1]))
# Out:
# A base de dados apresenta 32960 registro (imoveis) e 9 variaveis

# %%
import pandas as pd
data = [['Fulano', 12, 7.0, True],
        ['Sicrano', 15, 3.5, False], 
        ['Beltrano', 18, 9.3, True]]
dados = pd.DataFrame(data, 
        columns = ['Aluno', 'Idade', 'Nota', 'Aprovado'])
dados
# Out:
#       Aluno  Idade  Nota  Aprovado
# 0    Fulano     12   7.0      True
# 1   Sicrano     15   3.5     False
# 2  Beltrano     18   9.3      True

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, columns=['Tipos De Dados'])
tipos_de_dados.columns.na
tipos_de_dados
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-0d3ac7488466> in <module>
#       1 tipos_de_dados = pd.DataFrame(dados.dtypes, columns=['Tipos De Dados'])
# ----> 2 tipos_de_dados.columns = 'Variaveis'
#       3 tipos_de_dados
#
# ~\anaconda3\envs\alura_pandas\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\envs\alura_pandas\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
# ...
